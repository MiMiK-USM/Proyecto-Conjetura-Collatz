# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nicom\appdata\roaming\python\python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nicom\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nicom\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nicom\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\nicom\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\nicom\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def secuencia_collatz(n):
    trayectoria = [n]
    while n > 1:
        if n % 2 == 0:
            n = n//2
        else:
            n = 3 * n + 1
            trayectoria.append(n)
    return trayectoria
print(secuencia_collatz(27))
# Out:
# [27, 82, 124, 94, 142, 214, 322, 484, 364, 274, 412, 310, 466, 700, 526, 790, 1186, 1780, 1336, 502, 754, 1132, 850, 1276, 958, 1438, 2158, 3238, 4858, 7288, 2734, 4102, 6154, 9232, 1732, 1300, 976, 184, 70, 106, 160, 16]

# %%
tiempos_vuelo = []
altitud_maxima = []
for i in range(1, 10001):
    t = secuencia_collatz(i)
    tiempos_vuelo.append(len(t) - 1)
    altitud_maxima.append(max(t))

# %%
import matplotlib.pyplot as plt
datos = secuencia_collatz(27)
plt.plot(datos)
plt.title("Trayectoria de Collatz para n=27")
plt.xlabel("Pasos")
plt.xlabel("Valor")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(tiempos_vuelo, bins=100, color='orange', edgecolor='black')
plt.title("Histograma de Tiempos de Vuelo (n=1 hasta 10.000)")
plt.xlabel("Pasos para llegar a 1")
plt.ylabel("Cantidad de números")
plt.show()

# %%
plt.figure(figsize=(10, 6))
numeros = list(range(1, 10001)) 
plt.scatter(numeros, tiempos_vuelo, s=1, alpha=0.5)
plt.title("Dispersión: Número inicial vs Tiempo de Vuelo")
plt.xlabel("Número inicial (n)")
plt.ylabel("Tiempo de Vuelo (pasos)")
plt.show()

# %%
# Unimos el número con su tiempo de vuelo
# 'numeros' es del 1 al 10.000, 'tiempos_vuelo' son los resultados
resultados = list(zip(range(1, 10001), tiempos_vuelo))

# Ordenamos de mayor a menor según el tiempo de vuelo
top_10 = sorted(resultados, key=lambda x: x[1], reverse=True)[:10]

print("--- TOP 10 NÚMEROS CON MAYOR TIEMPO DE VUELO ---")
for n, tiempo in top_10:
    print(f"Número: {n} -> Tiempo de vuelo: {tiempo} pasos")
# Out:
# --- TOP 10 NÚMEROS CON MAYOR TIEMPO DE VUELO ---
# Número: 6171 -> Tiempo de vuelo: 96 pasos
# Número: 9257 -> Tiempo de vuelo: 95 pasos
# Número: 6943 -> Tiempo de vuelo: 94 pasos
# Número: 7963 -> Tiempo de vuelo: 92 pasos
# Número: 8959 -> Tiempo de vuelo: 90 pasos
# Número: 6591 -> Tiempo de vuelo: 89 pasos
# Número: 9887 -> Tiempo de vuelo: 88 pasos
# Número: 9897 -> Tiempo de vuelo: 88 pasos
# Número: 3711 -> Tiempo de vuelo: 87 pasos
# Número: 7422 -> Tiempo de vuelo: 87 pasos

# %%
import pandas as pd

def info_collatz(n):
    t = 0
    a_max = n
    valor_actual = n
    while valor_actual > 1:
        if valor_actual % 2 == 0:
            valor_actual //= 2
        else:
            valor_actual = 3 * valor_actual + 1
        t += 1
        if valor_actual > a_max:
            a_max = valor_actual
    return t, a_max

# 1. Generar los datos hasta 100,000
n_final = 100000
datos = []

for i in range(1, n_final + 1):
    tiempo, altitud = info_collatz(i)
    datos.append([i, tiempo, altitud])

# 2. Crear el DataFrame con los nombres de la guía
df = pd.DataFrame(datos, columns=['n (La Manzana)', 'T(n) (Pasos que dio)', 'A(n) (Altura que alcanzó)'])

# 3. Exportar a CSV (este es el archivo que le entregas a tu equipo)
df.to_csv('datos_collatz_100k.csv', index=False)

print("¡Archivo 'datos_collatz_100k.csv' creado con éxito!")
# Out:
# ¡Archivo 'datos_collatz_100k.csv' creado con éxito!
